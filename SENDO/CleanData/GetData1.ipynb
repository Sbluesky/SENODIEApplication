# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Fill the blanks
# ac link = "https://drive.google.com/open?id="
# aa link = "https://drive.google.com/open?id="
# ab link = "https://drive.google.com/open?id="
link = "https://drive.google.com/open?id="
fluff, id = link.split('=')

downloaded = drive.CreateFile({'id':id}) 
#downloaded.GetContentFile('time_user_product_ab.csv') 
downloaded.GetContentFile('all_data(1).csv')

# %%
data = pd.read_csv('all_data(1).csv', header = None)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 4 columns):
# 0    object
# 1    int64
# 2    int64
# 3    int64
# dtypes: int64(3), object(1)
# memory usage: 64.8+ MB

# %%
data.head(10)
# Out:
#                                   0     1     2  3
# 0  000021E7765634E8A1A1E27DE21E7DF3   274   274  1
# 1  000021E7765634E8A1A1E27DE21E7DF3   675   675  2
# 2  000021E7765634E8A1A1E27DE21E7DF3  1665  1665  1
# 3  000021E7765634E8A1A1E27DE21E7DF3  1844  1844  1
# 4  00003D04C11A33F674B8F64CB1BAA004   536   536  1
# 5  00003D04C11A33F674B8F64CB1BAA004   539   539  1
# 6  00004022C1300264544213050008F70D   243   243  2
# 7  00004022C1300264544213050008F70D  1091  1091  3
# 8  00005F933267D65FF8159DC1A6C70925  1674  1674  1
# 9  000070AD27611BAD348048F741DF5B19    57    57  2

# %%
data4 = pd.DataFrame(columns = ['user_id','belong_cate_lvl3_id', 'rating'])
data4['user_id'] = data[0]
data4['belong_cate_lvl3_id'] = data[1]
data4['rating'] = data[3]
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 3 columns):
# user_id                object
# belong_cate_lvl3_id    int64
# rating                 int64
# dtypes: int64(2), object(1)
# memory usage: 48.6+ MB

# %%
data4 = data4.sort_values(by = ['user_id'])
data4.head(20)
# Out:
#                              user_id  belong_cate_lvl3_id  rating
# 0   000021E7765634E8A1A1E27DE21E7DF3                  274       1
# 1   000021E7765634E8A1A1E27DE21E7DF3                  675       2
# 2   000021E7765634E8A1A1E27DE21E7DF3                 1665       1
# 3   000021E7765634E8A1A1E27DE21E7DF3                 1844       1
# 4   00003D04C11A33F674B8F64CB1BAA004                  536       1
# 5   00003D04C11A33F674B8F64CB1BAA004                  539       1
# 6   00004022C1300264544213050008F70D                  243       2
# 7   00004022C1300264544213050008F70D                 1091       3
# 8   00005F933267D65FF8159DC1A6C70925                 1674       1
# 9   000070AD27611BAD348048F741DF5B19                   57       2
# 10  000070AD27611BAD348048F741DF5B19                 1572       1
# 16  0000C89FF2311CE11E9D9FB5B0C38BD1                 1806       1
# 14  0000C89FF2311CE11E9D9FB5B0C38BD1                 1399       1
# ...

# %%
data4 ['USER_ID'] = data4['user_id']
data4['us_ID'] = 0
data4.head(10)
# Out:
#                             user_id  ...  us_ID
# 0  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 1  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 2  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 3  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 4  00003D04C11A33F674B8F64CB1BAA004  ...      0
# 5  00003D04C11A33F674B8F64CB1BAA004  ...      0
# 6  00004022C1300264544213050008F70D  ...      0
# 7  00004022C1300264544213050008F70D  ...      0
# 8  00005F933267D65FF8159DC1A6C70925  ...      0
# 9  000070AD27611BAD348048F741DF5B19  ...      0
#
# [10 rows x 5 columns]

# %%
for i in range(1,100000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data4.head(10)
# Out:
#                             user_id  ...  us_ID
# 0  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 1  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 2  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 3  000021E7765634E8A1A1E27DE21E7DF3  ...      0
# 4  00003D04C11A33F674B8F64CB1BAA004  ...      1
# 5  00003D04C11A33F674B8F64CB1BAA004  ...      1
# 6  00004022C1300264544213050008F70D  ...      2
# 7  00004022C1300264544213050008F70D  ...      2
# 8  00005F933267D65FF8159DC1A6C70925  ...      3
# 9  000070AD27611BAD348048F741DF5B19  ...      4
#
# [10 rows x 5 columns]

# %%
for i in range(100000,200000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(200000,300000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(300000,400000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(400000,500000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data4.to_csv(r'clean_cateid.csv')

# %%
for i in range(500000,600000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(600000,700000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(700000,800000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(800000,900000):
  if data4.iloc[i,4] == 0:
    print('FALSE!')
    break
# Out:
# FALSE!

# %%
data4 = pd.read_csv('clean_cateid.csv')
data4 = data4.drop(columns = ['Unnamed: 0'])
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 5 columns):
# user_id                object
# belong_cate_lvl3_id    int64
# rating                 int64
# USER_ID                object
# us_ID                  int64
# dtypes: int64(3), object(2)
# memory usage: 81.0+ MB

# %%
for i in range(800000,900000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(900000,1000000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data4.to_csv(r'clean_cateid1.csv')

# %%
for i in range(1100000,1200000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1200000,1300000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1300000,1400000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1400000,1500000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1500000,1600000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1600000,1700000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1700000,1800000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1800000,1900000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1900000,2000000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(2000000,2124668):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data4['user_id'].nunique()
# Out:
# 799484

# %%
data4['us_ID'].max()
# Out:
# 799483

# %%
data4.tail(20)
# Out:
#                                   user_id  ...   us_ID
# 2124648  FFFF7432B3FAC47EF0DC122B9B3C5114  ...  799480
# 2124649  FFFF7E7D68AF1C88E282140235E87D37  ...  799481
# 2124650  FFFF9ABF51D864A05C7F140C7E7EF138  ...  799482
# 2124651  FFFF9ABF51D864A05C7F140C7E7EF138  ...  799482
# 2124652  FFFF9ABF51D864A05C7F140C7E7EF138  ...  799482
# 2124653  FFFF9ABF51D864A05C7F140C7E7EF138  ...  799482
# 2124654  FFFF9ABF51D864A05C7F140C7E7EF138  ...  799482
# 2124655  FFFF9ABF51D864A05C7F140C7E7EF138  ...  799482
# 2124656  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124657  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124658  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124659  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124660  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124661  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124662  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# 2124663  FFFFAB920C0D044E678B261FAA01F795  ...  799483
# ...

# %%
data4.to_csv(r'clean_cateid2.csv')

# %%
for i in range(1100000,1100001):
  if data4.iloc[i,4] == 0:
    print ("TRUE")
    break
print("okey!")
# Out:
# okey!

# %%
data_aa = pd.read_csv('time_user_product.csv')
data_aa.head(10)
# Out:
#    Unnamed: 0  ... product_id
# 0           0  ...    2920660
# 1           1  ...    1885579
# 2           2  ...    2633702
# 3           3  ...    2936475
# 4           4  ...    2146364
# 5           5  ...    2764320
# 6           6  ...    2863509
# 7           7  ...    2049133
# 8           8  ...    2263589
# 9           9  ...    2370825
#
# [10 rows x 4 columns]

# %%
data_ab = pd.read_csv('time_user_product_ab.csv')
data_ab.head(10)
# Out:
#    Unnamed: 0  ... product_id
# 0           0  ...    1348368
# 1           1  ...    2490499
# 2           2  ...    2712926
# 3           3  ...    2845665
# 4           4  ...    2819143
# 5           5  ...    2824435
# 6           6  ...    2721390
# 7           7  ...    3016214
# 8           8  ...    2829143
# 9           9  ...    2489269
#
# [10 rows x 4 columns]

# %%
data_ac = pd.read_csv('time_user_product_ac.csv')
data_ac.head(10)
# Out:
#    Unnamed: 0  ... product_id
# 0           0  ...    3089383
# 1           1  ...    3168462
# 2           2  ...    2955738
# 3           3  ...    2413323
# 4           4  ...    3169255
# 5           5  ...    3169219
# 6           6  ...    2986587
# 7           7  ...    2062326
# 8           8  ...    2699057
# 9           9  ...    3025094
#
# [10 rows x 4 columns]

# %%
data_aa.info()
data_ab.info()
data_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398354 entries, 0 to 2398353
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 73.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398168 entries, 0 to 2398167
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 73.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302411 entries, 0 to 2302410
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 70.3+ MB

# %%
data = pd.concat([data_aa, data_ab, data_ac], axis = 0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7098933 entries, 0 to 2302410
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 270.8+ MB

# %%
data = data.drop(columns=['Unnamed: 0'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148733 entries, 0 to 5148732
# Data columns (total 5 columns):
# user_id       object
# product_id    int64
# rating        int64
# user_id1      object
# USER_ID       int64
# dtypes: int64(3), object(2)
# memory usage: 196.4+ MB

# %%
data['user_id'].nunique()
# Out:
# 799484

# %%
data['product_id'].nunique()
# Out:
# 620651

# %%
data1 = data.drop(columns=['time'])

# %%
data2 = data1.groupby(by = ['user_id', 'product_id'], as_index = True)['product_id'].value_counts()
data2
# Out:
# user_id                           product_id  product_id
# 000021E7765634E8A1A1E27DE21E7DF3  765942      765942        2
#                                   1146920     1146920       1
#                                   3037477     3037477       1
#                                   3070164     3070164       1
# 00003D04C11A33F674B8F64CB1BAA004  2249761     2249761       1
#                                                            ..
# FFFFAB920C0D044E678B261FAA01F795  3186839     3186839       1
#                                   3192931     3192931       1
#                                   3205557     3205557       1
#                                   3233495     3233495       1
#                                   3258189     3258189       1
# Name: product_id, Length: 5148733, dtype: int64

# %%
data2.to_csv(r'all_data.csv')

# %%
data3 = pd.read_csv('all_data.csv', header = None)
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148733 entries, 0 to 5148732
# Data columns (total 4 columns):
# 0    object
# 1    int64
# 2    int64
# 3    int64
# dtypes: int64(3), object(1)
# memory usage: 157.1+ MB

# %%
data4 = pd.DataFrame(columns = ['user_id','product_id', 'rating'])
data4['user_id'] = data3[0]
data4['product_id'] = data3[1]
data4['rating'] = data3[3]
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148733 entries, 0 to 5148732
# Data columns (total 3 columns):
# user_id       object
# product_id    int64
# rating        int64
# dtypes: int64(2), object(1)
# memory usage: 117.8+ MB

# %%
data4.head(10)
# Out:
#                             user_id  product_id  rating
# 0  000021E7765634E8A1A1E27DE21E7DF3      765942       2
# 1  000021E7765634E8A1A1E27DE21E7DF3     1146920       1
# 2  000021E7765634E8A1A1E27DE21E7DF3     3037477       1
# 3  000021E7765634E8A1A1E27DE21E7DF3     3070164       1
# 4  00003D04C11A33F674B8F64CB1BAA004     2249761       1
# 5  00003D04C11A33F674B8F64CB1BAA004     2796826       1
# 6  00004022C1300264544213050008F70D     1274524       2
# 7  00004022C1300264544213050008F70D     1274557       1
# 8  00004022C1300264544213050008F70D     2998880       2
# 9  00005F933267D65FF8159DC1A6C70925     2569826       1

# %%
data4.to_csv(r'all_rating.csv')

# %%
data4['user_id1'] = data4['user_id'] 
data4['USER_ID'] = 0
data4.head(3)
# Out:
#                             user_id  ...  USER_ID
# 0  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 1  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 2  000021E7765634E8A1A1E27DE21E7DF3  ...        0
#
# [3 rows x 5 columns]

# %%
for i in range(1,100000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(100000,200000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data4['USER_ID'].max()
# Out:
# 185742

# %%
data4.to_csv(r'cleanid.csv')

# %%
for i in range(200000,300000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(300000,400000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(400000,500000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
link = "https://drive.google.com/open?id="
fluff, id = link.split('=')

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('cleanid.csv')
data4 = pd.read_csv('cleanid.csv')
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148733 entries, 0 to 5148732
# Data columns (total 6 columns):
# Unnamed: 0    int64
# user_id       object
# product_id    int64
# rating        int64
# user_id1      object
# USER_ID       int64
# dtypes: int64(4), object(2)
# memory usage: 235.7+ MB

# %%
data4 = data4.drop(columns = ['Unnamed: 0'])
data4.head(5)
# Out:
#                             user_id  ...  USER_ID
# 0  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 1  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 2  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 3  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 4  00003D04C11A33F674B8F64CB1BAA004  ...        1
#
# [5 rows x 5 columns]

# %%
for i in range(500000,600000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(600000,700000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(700000,800000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(800000,900000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(900000,1000000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1000000,1100000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1100000,1200000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(3700000,3800000):
  if data.iloc[i,4] == 0:
    print ("True")
    break
  
print ("okey")
# Out:
# okey

# %%
data['USER_ID'].max()
# Out:
# 574646

# %%
data4 = pd.read_csv('cleanid.csv')

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148733 entries, 0 to 5148732
# Data columns (total 6 columns):
# Unnamed: 0    int64
# user_id       object
# product_id    int64
# rating        int64
# user_id1      object
# USER_ID       int64
# dtypes: int64(4), object(2)
# memory usage: 235.7+ MB

# %%
data4 = data4.drop(columns = ['Unnamed: 0'])
data4.head(5)
# Out:
#                             user_id  ...  USER_ID
# 0  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 1  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 2  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 3  000021E7765634E8A1A1E27DE21E7DF3  ...        0
# 4  00003D04C11A33F674B8F64CB1BAA004  ...        1
#
# [5 rows x 5 columns]

# %%
for i in range(1200000,1300000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1300000,1400000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data.to_csv(r'cleanid_4.csv')

# %%
for i in range(1400000,1500000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1500000,1600000):
  if data4.iloc[i,0] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(2000000,2100000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2100000,2200000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2200000,2300000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2300000,2400000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2400000,2500000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2500000,2600000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2600000,2700000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2700000,2800000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2800000,2900000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(2900000,3000000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3000000,3100000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3100000,3200000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3200000,3300000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3300000,3400000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3400000,3500000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3500000,3600000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
data = pd.read_csv('cleanid_4.csv')

# %%
data = data.drop(columns=['Unnamed: 0'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5148733 entries, 0 to 5148732
# Data columns (total 5 columns):
# user_id       object
# product_id    int64
# rating        int64
# user_id1      object
# USER_ID       int64
# dtypes: int64(3), object(2)
# memory usage: 196.4+ MB

# %%
for i in range(3600000,3700000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(3700000,3800000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
data.to_csv(r'cleanid_5.csv')

# %%
for i in range(3800000,3900000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(5100000,5148734):
  if data.iloc[i,4] == 0:
    print ("True")
    break
  
print ("okey")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-65e376a21200> in <module>()
#       1 for i in range(5100000,5148734):
# ----> 2   if data.iloc[i,4] == 0:
#       3     print ("True")
#       4     break
#       5
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
#    2094             return self._getitem_lowerdim(tup)
#
# ...

# %%
data['USER_ID'].max()
# Out:
# 799483

# %%
data['user_id'].nunique()
# Out:
# 799484

# %%
for i in range(3900000,4000000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
data.to_csv(r'cleanid_6.csv')

# %%
for i in range(4000000,4100000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4100000,4200000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4200000,4300000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4300000,4400000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4400000,4500000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4500000,4600000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4600000,4700000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4700000,4800000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4800000,4900000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(4900000,5000000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(5000000,5100000):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]

# %%
for i in range(5100000,5148734):
  if data.iloc[i,0] != data.iloc[i-1,3]:
    data.iloc[i,4] = data.iloc[i-1,4] + 1
  else:
    data.iloc[i,4] = data.iloc[i-1,4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-1c19074cc9b9> in <module>()
#       1 for i in range(5100000,5148734):
# ----> 2   if data.iloc[i,0] != data.iloc[i-1,3]:
#       3     data.iloc[i,4] = data.iloc[i-1,4] + 1
#       4   else:
#       5     data.iloc[i,4] = data.iloc[i-1,4]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1416                 except (KeyError, IndexError, AttributeError):
#    1417                     pass
# -> 1418             return self._getitem_tuple(key)
#    1419         else:
#    1420             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    2090     def _getitem_tuple(self, tup):
#    2091
# -> 2092         self._has_valid_tuple(tup)
#    2093         try:
# ...
