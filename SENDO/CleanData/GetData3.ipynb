# %% [markdown]
# # **Clean Data to prepare train model**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Fill the blanks
 link = "https://drive.google.com/open?id="
# aa link = "https://drive.google.com/open?id="
#ab link = "https://drive.google.com/open?id="
fluff, id = link.split('=')

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('Sendo_ac.csv')

# %%
data_aa = pd.read_csv('Sendo_aa.csv')
data_aa = data_aa.drop(columns=['Unnamed: 0'])
data_aa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398354 entries, 0 to 2398353
# Data columns (total 10 columns):
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(4), object(6)
# memory usage: 183.0+ MB

# %%
data_ab = pd.read_csv('Sendo_ab.csv')
data_ab = data_ab.drop(columns=['Unnamed: 0'])
data_ab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398168 entries, 0 to 2398167
# Data columns (total 10 columns):
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(4), object(6)
# memory usage: 183.0+ MB

# %%
data_ac = pd.read_csv('Sendo_ac.csv')
data_ac = data_ac.drop(columns=['Unnamed: 0'])
data_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302411 entries, 0 to 2302410
# Data columns (total 10 columns):
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(4), object(6)
# memory usage: 175.7+ MB

# %%
data = pd.concat([data_aa, data_ab, data_ac], axis = 0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7098933 entries, 0 to 2302410
# Data columns (total 10 columns):
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(4), object(6)
# memory usage: 595.8+ MB

# %%
data2 = data.groupby(by = ['user_id','belong_cate_lvl3_id'], as_index = True)['belong_cate_lvl3_id'].value_counts()
data2
# Out:
# user_id                           belong_cate_lvl3_id  belong_cate_lvl3_id
# 000021E7765634E8A1A1E27DE21E7DF3  274                  274                     1
#                                   675                  675                     2
#                                   1665                 1665                    1
#                                   1844                 1844                    1
# 00003D04C11A33F674B8F64CB1BAA004  536                  536                     1
#                                                                               ..
# FFFFAB920C0D044E678B261FAA01F795  1692                 1692                    2
#                                   1698                 1698                   19
#                                   1700                 1700                    4
#                                   1777                 1777                    8
#                                   1855                 1855                    2
# ...

# %%
data2.to_csv(r'all_data.csv')

# %%
data3 = pd.read_csv('all_data.csv', header = None)
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 4 columns):
# 0    object
# 1    int64
# 2    int64
# 3    int64
# dtypes: int64(3), object(1)
# memory usage: 64.8+ MB

# %%
data4 = pd.DataFrame(columns = ['user_id','belong_cate_lvl3_id', 'rating'])
data4['user_id'] = data3[0]
data4['belong_cate_lvl3_id'] = data3[1]
data4['rating'] = data3[3]
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 3 columns):
# user_id                object
# belong_cate_lvl3_id    int64
# rating                 int64
# dtypes: int64(2), object(1)
# memory usage: 48.6+ MB

# %%
data4.head(10)
# Out:
#                             user_id  belong_cate_lvl3_id  rating
# 0  000021E7765634E8A1A1E27DE21E7DF3                  274       1
# 1  000021E7765634E8A1A1E27DE21E7DF3                  675       2
# 2  000021E7765634E8A1A1E27DE21E7DF3                 1665       1
# 3  000021E7765634E8A1A1E27DE21E7DF3                 1844       1
# 4  00003D04C11A33F674B8F64CB1BAA004                  536       1
# 5  00003D04C11A33F674B8F64CB1BAA004                  539       1
# 6  00004022C1300264544213050008F70D                  243       2
# 7  00004022C1300264544213050008F70D                 1091       3
# 8  00005F933267D65FF8159DC1A6C70925                 1674       1
# 9  000070AD27611BAD348048F741DF5B19                   57       2

# %%
data4 = data4.sort_values(by = ['user_id'])
data4.head(20)
# Out:
#                              user_id  belong_cate_lvl3_id  rating
# 0   000021E7765634E8A1A1E27DE21E7DF3                  274       1
# 1   000021E7765634E8A1A1E27DE21E7DF3                  675       2
# 2   000021E7765634E8A1A1E27DE21E7DF3                 1665       1
# 3   000021E7765634E8A1A1E27DE21E7DF3                 1844       1
# 4   00003D04C11A33F674B8F64CB1BAA004                  536       1
# 5   00003D04C11A33F674B8F64CB1BAA004                  539       1
# 6   00004022C1300264544213050008F70D                  243       2
# 7   00004022C1300264544213050008F70D                 1091       3
# 8   00005F933267D65FF8159DC1A6C70925                 1674       1
# 9   000070AD27611BAD348048F741DF5B19                   57       2
# 10  000070AD27611BAD348048F741DF5B19                 1572       1
# 16  0000C89FF2311CE11E9D9FB5B0C38BD1                 1806       1
# 14  0000C89FF2311CE11E9D9FB5B0C38BD1                 1399       1
# ...

# %%
data4.loc[data4.rating > 5, 'rating'] = 5

# %%
data4['rating'].max()
# Out:
# 5

# %%
data4 = pd.read_csv('rating5.csv')
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 4 columns):
# Unnamed: 0             int64
# user_id                object
# belong_cate_lvl3_id    int64
# rating                 int64
# dtypes: int64(3), object(1)
# memory usage: 64.8+ MB

# %%
data4 = data4.drop(columns=['Unnamed: 0'])

# %%
data4['cate_id3'] = data4['belong_cate_lvl3_id']
data4['CATE_ID'] = 0
data4.head(20)
# Out:
#                              user_id  belong_cate_lvl3_id  ...  cate_id3  CATE_ID
# 0   000021E7765634E8A1A1E27DE21E7DF3                  274  ...       274        0
# 1   000021E7765634E8A1A1E27DE21E7DF3                  675  ...       675        0
# 2   000021E7765634E8A1A1E27DE21E7DF3                 1665  ...      1665        0
# 3   000021E7765634E8A1A1E27DE21E7DF3                 1844  ...      1844        0
# 4   00003D04C11A33F674B8F64CB1BAA004                  536  ...       536        0
# 5   00003D04C11A33F674B8F64CB1BAA004                  539  ...       539        0
# 6   00004022C1300264544213050008F70D                  243  ...       243        0
# 7   00004022C1300264544213050008F70D                 1091  ...      1091        0
# 8   00005F933267D65FF8159DC1A6C70925                 1674  ...      1674        0
# 9   000070AD27611BAD348048F741DF5B19                   57  ...        57        0
# ...

# %%
data4 = data4.sort_values(by =['belong_cate_lvl3_id'])
data4.head(20)
# Out:
#                                   user_id  ...  CATE_ID
# 1802762  D9175D0B823CE4E5DCF31DAC55A14AFF  ...        0
# 527859   3F614ED18E0E075CBC39444AE54D39CF  ...        0
# 527849   3F6118AF6E8A18907334BAF875E4C82F  ...        0
# 527816   3F607D704D2B4112273C0F266CB3FF4F  ...        0
# 527785   3F5FBFF95480ECE4D7676E6FF19F13C9  ...        0
# 1894844  E42FA05399378A363487773F15AADE60  ...        0
# 527705   3F5E7D5C31CFB528B7E2FC23F6F2190E  ...        0
# 527649   3F5D4E706220B71FAFBC0CB05939F4FA  ...        0
# 1894897  E43147681D59DF2F98B88F70392DC073  ...        0
# 527624   3F5C0C701BBCCAFC6F11907E04D102A0  ...        0
# 527607   3F5B778C5E72E29CFC5E8C0AB2AFBB3A  ...        0
# 1894937  E43261C543A80DAB4ECDEB53C310BA32  ...        0
# 527548   3F5A2110209F5F834D02C7AF79508616  ...        0
# 527514   3F594FD99C0F8C877D66D0E249D1C57D  ...        0
# 527463   3F57031CD0454D2F0A2A1EFBD3527FA9  ...        0
# 1895008  E4337B66570F6154D50F99FFF932797D  ...        0
# ...

# %%
for i in range(1,100000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(100000,200000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(200000,300000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(300000,400000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(400000,500000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(500000,600000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(600000,700000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(700000,800000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(800000,900000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(900000,1000000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1000000,1100000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1100000,1200000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1200000,1300000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1300000,1400000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1400000,1500000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1500000,1600000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1600000,1700000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1700000,1800000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1800000,1900000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(1900000,2000000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(2000000,2100000):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
for i in range(2100000,2124668):
  if data4.iloc[i,1] != data4.iloc[i-1,3]:
    data4.iloc[i,4] = data4.iloc[i-1,4] + 1
  else:
    data4.iloc[i,4] = data4.iloc[i-1,4]

# %%
data4['belong_cate_lvl3_id'].nunique()
# Out:
# 952

# %%
data4['CATE_ID'].max()
# Out:
# 951

# %%
data4.to_csv(r'rating6.csv')

# %%
data4.to_csv(r'clean_cate.csv')

# %%
data4.tail(20)
# Out:
#                                   user_id  ...  CATE_ID
# 1731415  D09ECD1D9DF6907F9B0ED7F74D51320D  ...      950
# 432132   33DB45B75992177A6FA9088CE2E8954A  ...      950
# 1516124  B6C46AE7F35B0A6C54321318B554FE07  ...      950
# 1940775  E9B9808E09EE12E70816B7D20A1BD5BE  ...      950
# 949724   722DD33475BE592DCBD366D8653DA047  ...      950
# 1722026  CF72900081A48ACC1CB0D6885BA66935  ...      950
# 1770339  D54CD98D393F200E3199D193A1DD1AB8  ...      950
# 1672290  C97938EDAC418C7F9AB6F4B1C56ECBDD  ...      950
# 838538   64E77D9338E373487D33F752CB0E2D6F  ...      951
# 456960   36F06509BA6D67AFAC938CBC67E6A19D  ...      951
# 630521   4BA1F6C9BA8210EE216D1C108E2D997D  ...      951
# 452258   365575863F59481AB24F447769A37BED  ...      951
# 1714104  CE81F937EFA1ED6728682A656934AEF5  ...      951
# 345736   296C008A05247119FA5C111E2573F0A9  ...      951
# 1026433  7B76545ADCC367E7D7458F5437C4CABB  ...      951
# 560809   434AAA4C36BE7A4DE0EE4A8BFAC34E19  ...      951
# ...

# %%
data3 = pd.read_csv('clean_cateid2.csv')
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2124668 entries, 0 to 2124667
# Data columns (total 6 columns):
# Unnamed: 0             int64
# user_id                object
# belong_cate_lvl3_id    int64
# rating                 int64
# USER_ID                object
# us_ID                  int64
# dtypes: int64(4), object(2)
# memory usage: 97.3+ MB

# %%
data3 = data3.drop(columns=['Unnamed: 0','USER_ID'])
data3.head(20)
# Out:
#                              user_id  belong_cate_lvl3_id  rating  us_ID
# 0   000021E7765634E8A1A1E27DE21E7DF3                  274       1      0
# 1   000021E7765634E8A1A1E27DE21E7DF3                  675       2      0
# 2   000021E7765634E8A1A1E27DE21E7DF3                 1665       1      0
# 3   000021E7765634E8A1A1E27DE21E7DF3                 1844       1      0
# 4   00003D04C11A33F674B8F64CB1BAA004                  536       1      1
# 5   00003D04C11A33F674B8F64CB1BAA004                  539       1      1
# 6   00004022C1300264544213050008F70D                  243       2      2
# 7   00004022C1300264544213050008F70D                 1091       3      2
# 8   00005F933267D65FF8159DC1A6C70925                 1674       1      3
# 9   000070AD27611BAD348048F741DF5B19                   57       2      4
# 10  000070AD27611BAD348048F741DF5B19                 1572       1      4
# 11  0000C89FF2311CE11E9D9FB5B0C38BD1                 1806       1      5
# ...

# %%
data4 = data4.sort_values(by=['user_id'])
data4.head(20)
# Out:
#                              user_id  belong_cate_lvl3_id  ...  cate_id3  CATE_ID
# 3   000021E7765634E8A1A1E27DE21E7DF3                 1844  ...      1844      867
# 1   000021E7765634E8A1A1E27DE21E7DF3                  675  ...       675      244
# 0   000021E7765634E8A1A1E27DE21E7DF3                  274  ...       274      148
# 2   000021E7765634E8A1A1E27DE21E7DF3                 1665  ...      1665      745
# 4   00003D04C11A33F674B8F64CB1BAA004                  536  ...       536      170
# 5   00003D04C11A33F674B8F64CB1BAA004                  539  ...       539      173
# 7   00004022C1300264544213050008F70D                 1091  ...      1091      373
# 6   00004022C1300264544213050008F70D                  243  ...       243      126
# 8   00005F933267D65FF8159DC1A6C70925                 1674  ...      1674      751
# 10  000070AD27611BAD348048F741DF5B19                 1572  ...      1572      691
# ...

# %%
data4 = data4.drop(columns=['cate_id3'])
data4.tail(20)
# Out:
#                                   user_id  belong_cate_lvl3_id  rating  CATE_ID
# 2124648  FFFF7432B3FAC47EF0DC122B9B3C5114                 1777       1      810
# 2124649  FFFF7E7D68AF1C88E282140235E87D37                 1289       1      491
# 2124650  FFFF9ABF51D864A05C7F140C7E7EF138                  646       1      226
# 2124651  FFFF9ABF51D864A05C7F140C7E7EF138                  543       4      176
# 2124655  FFFF9ABF51D864A05C7F140C7E7EF138                   65       5       35
# 2124654  FFFF9ABF51D864A05C7F140C7E7EF138                   22       2       10
# 2124652  FFFF9ABF51D864A05C7F140C7E7EF138                 1370       5      537
# 2124653  FFFF9ABF51D864A05C7F140C7E7EF138                   25       1       13
# 2124658  FFFFAB920C0D044E678B261FAA01F795                 1700       4      767
# 2124663  FFFFAB920C0D044E678B261FAA01F795                   36       1       18
# 2124661  FFFFAB920C0D044E678B261FAA01F795                 1777       5      810
# ...

# %%
data4['USER_ID'] = data3['us_ID']
data4.tail(20)
# Out:
#                                   user_id  ...  USER_ID
# 2124648  FFFF7432B3FAC47EF0DC122B9B3C5114  ...   799480
# 2124649  FFFF7E7D68AF1C88E282140235E87D37  ...   799481
# 2124650  FFFF9ABF51D864A05C7F140C7E7EF138  ...   799482
# 2124651  FFFF9ABF51D864A05C7F140C7E7EF138  ...   799482
# 2124655  FFFF9ABF51D864A05C7F140C7E7EF138  ...   799482
# 2124654  FFFF9ABF51D864A05C7F140C7E7EF138  ...   799482
# 2124652  FFFF9ABF51D864A05C7F140C7E7EF138  ...   799482
# 2124653  FFFF9ABF51D864A05C7F140C7E7EF138  ...   799482
# 2124658  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124663  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124661  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124656  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124660  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124662  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124667  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# 2124666  FFFFAB920C0D044E678B261FAA01F795  ...   799483
# ...

# %%
data4.to_csv(r'CLEAN_CATELV3.CSV')
