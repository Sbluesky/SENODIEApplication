# %% [markdown]
# # **Clean Data to prepare train model**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Fill the blanks
link = "https://drive.google.com/open?id="
# aa link = "https://drive.google.com/open?id="
# ab link = "https://drive.google.com/open?id="
fluff, id = link.split('=')

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('time_user_product_ac.csv')

# %%
data_aa = pd.read_csv('time_user_product.csv')
data_aa.head(10)
# Out:
#    Unnamed: 0  ... product_id
# 0           0  ...    2920660
# 1           1  ...    1885579
# 2           2  ...    2633702
# 3           3  ...    2936475
# 4           4  ...    2146364
# 5           5  ...    2764320
# 6           6  ...    2863509
# 7           7  ...    2049133
# 8           8  ...    2263589
# 9           9  ...    2370825
#
# [10 rows x 4 columns]

# %%
data_ab = pd.read_csv('time_user_product_ab.csv')
data_ab.head(10)
# Out:
#    Unnamed: 0  ... product_id
# 0           0  ...    1348368
# 1           1  ...    2490499
# 2           2  ...    2712926
# 3           3  ...    2845665
# 4           4  ...    2819143
# 5           5  ...    2824435
# 6           6  ...    2721390
# 7           7  ...    3016214
# 8           8  ...    2829143
# 9           9  ...    2489269
#
# [10 rows x 4 columns]

# %%
data_ac = pd.read_csv('time_user_product_ac.csv')
data_ac.head(10)
# Out:
#    Unnamed: 0  ... product_id
# 0           0  ...    3089383
# 1           1  ...    3168462
# 2           2  ...    2955738
# 3           3  ...    2413323
# 4           4  ...    3169255
# 5           5  ...    3169219
# 6           6  ...    2986587
# 7           7  ...    2062326
# 8           8  ...    2699057
# 9           9  ...    3025094
#
# [10 rows x 4 columns]

# %%
data_aa.info()
data_ab.info()
data_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398354 entries, 0 to 2398353
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 73.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398168 entries, 0 to 2398167
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 73.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302411 entries, 0 to 2302410
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 70.3+ MB

# %%
data = pd.concat([data_aa, data_ab, data_ac], axis = 0)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7098933 entries, 0 to 2302410
# Data columns (total 4 columns):
# Unnamed: 0    int64
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(2), object(2)
# memory usage: 270.8+ MB

# %%
data = data.drop(columns=['Unnamed: 0'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7098933 entries, 0 to 2302410
# Data columns (total 3 columns):
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(1), object(2)
# memory usage: 216.6+ MB

# %%
data['user_id'].nunique()
# Out:
# 799484

# %%
data['product_id'].nunique()
# Out:
# 620651

# %%
data1 = data.drop(columns=['time'])

# %%
data2 = data.groupby(by = ['user_id', 'product_id'], as_index = True)['product_id'].value_counts()
data2
# Out:
# user_id                           product_id  product_id
# 000021E7765634E8A1A1E27DE21E7DF3  765942      765942        2
#                                   1146920     1146920       1
#                                   3037477     3037477       1
#                                   3070164     3070164       1
# 00003D04C11A33F674B8F64CB1BAA004  2249761     2249761       1
#                                   2796826     2796826       1
# 00004022C1300264544213050008F70D  1274524     1274524       2
#                                   1274557     1274557       1
#                                   2998880     2998880       2
# 00005F933267D65FF8159DC1A6C70925  2569826     2569826       1
# 000070AD27611BAD348048F741DF5B19  3091102     3091102       1
#                                   3093492     3093492       2
# 0000C89FF2311CE11E9D9FB5B0C38BD1  948229      948229        2
#                                   1438849     1438849       1
# ...

# %%
data1.to_csv('data_all.csv')
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-19-beb127f20aec> in <module>()
# ----> 1 data1.to_csv('data_all.csv')
#
# AttributeError: 'function' object has no attribute 'to_csv'
