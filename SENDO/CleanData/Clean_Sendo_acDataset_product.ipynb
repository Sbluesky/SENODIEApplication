# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Fill the blanks
link = "https://drive.google.com/open?id="
fluff, id = link.split('=')

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('sendo-ac.csv')  
data = pd.read_csv('sendo-ac.csv')
#data = data[0].str.split(',', expand=True)
# Show first 5 rows of dataset
data.sample(5)
# Out:
#          Unnamed: 0  ...                                               href
# 629657       629657  ...  https://www.sendo.vn/san-pham/sung-ban-chun-m9...
# 2282605     2282605  ...  https://www.sendo.vn/san-pham/dam-dinh-buom-vo...
# 636965       636965  ...  https://www.sendo.vn/san-pham/dong-ho-curren-c...
# 587714       587714  ...  https://www.sendo.vn/san-pham/ao-thun-nu-be-nh...
# 2093763     2093763  ...  https://www.sendo.vn/san-pham/dong-ho-de-ban-c...
#
# [5 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302411 entries, 0 to 2302410
# Data columns (total 11 columns):
# Unnamed: 0               int64
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(5), object(6)
# memory usage: 193.2+ MB

# %%
df_ac = data.drop(columns='Unnamed: 0', axis = 0)

df_ac.sample(10)
# Out:
#                         time  ...                                               href
# 2281421  2016-06-30 17:52:03  ...  https://www.sendo.vn/san-pham/chan-vay-ren-315...
# 1802069  2016-06-24 15:28:17  ...  https://www.sendo.vn/san-pham/do-ngu-bo-ngoi-c...
# 189480   2016-06-04 14:12:53  ...  https://www.sendo.vn/san-pham/gay-chup-hinh-tu...
# 1337284  2016-06-18 21:30:14  ...  https://www.sendo.vn/san-pham/sandal-vento-chi...
# 1942969  2016-06-26 19:49:27  ...  https://www.sendo.vn/san-pham/ao-so-mi-a090-31...
# 1673704  2016-06-23 08:58:51  ...  https://www.sendo.vn/san-pham/dam-co-tim-cuc-d...
# 1554777  2016-06-21 17:44:32  ...  https://www.sendo.vn/san-pham/set-dam-doi-phoi...
# 238409   2016-06-05 11:09:46  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 322308   2016-06-06 15:04:03  ...  https://www.sendo.vn/san-pham/quat-deo-usb-de-...
# 600091   2016-06-09 18:05:57  ...  https://www.sendo.vn/san-pham/khan-turban-hoa-...
#
# [10 rows x 10 columns]

# %%
df_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2302411 entries, 0 to 2302410
# Data columns (total 10 columns):
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(4), object(6)
# memory usage: 175.7+ MB

# %%
df_user = pd.DataFrame(columns=['user_id'])

# %%
df_user['user_id'] = df_ac['user_id'].unique()

# %%
df_user.to_csv(r'user_ac.csv')

# %%
df_user['user_id'].nunique()
# Out:
# 312403

# %%
df_time = pd.DataFrame(columns=['time', 'user_id', 'product_id'])

# %%
df_time['time'] = df_ac['time']
df_time['user_id'] = df_ac['user_id']
df_time['product_id'] = df_ac['product_id']

# %%
df_time.to_csv(r'time_user_product_ac.csv')

# %%
df_time.head(10)
# Out:
#                   time                           user_id  product_id
# 0  2016-06-02 09:00:02  DAB8D4AA14663C554D34B8BDF4D45E71     3089383
# 1  2016-06-02 09:00:02  03EDC0ACFF66FF2FAA4F45C74633D1F3     3168462
# 2  2016-06-02 09:00:03  4448A25615AC8ACCFF59CCC4725E6A9F     2955738
# 3  2016-06-02 09:00:03  C6AC1D01946EAE6FD78215F97495D4B2     2413323
# 4  2016-06-02 09:00:03  E3F74A77A235C9427DA1C4700CDBFE63     3169255
# 5  2016-06-02 09:00:04  C63647A5FE81A67C30C5FFBC7E46BA6D     3169219
# 6  2016-06-02 09:00:04  AA973AE131AED85AF67629AB45D939F0     2986587
# 7  2016-06-02 09:00:04  69B394F4D0C891DFD6C01BB1CAE2555A     2062326
# 8  2016-06-02 09:00:04  C7D1727E08921E1A94DD7C302E73A3D0     2699057
# 9  2016-06-02 09:00:04  7FA6F940333855D3EAC7B0694DEAFF8F     3025094

# %%
df_ab['href'].sample(10)
# Out:
# 1625956    https://www.sendo.vn/san-pham/do-boi-nu-xe-ta-...
# 1306720    https://www.sendo.vn/san-pham/hang-nhap-ao-can...
# 77000      https://www.sendo.vn/san-pham/lotion-ngan-ngua...
# 214324     https://www.sendo.vn/san-pham/binh-giu-nhiet-2...
# 1869348    https://www.sendo.vn/san-pham/jeans-ngan-cac-l...
# 1786179    https://www.sendo.vn/san-pham/hang-chong-tham-...
# 1566099    https://www.sendo.vn/san-pham/chiec-hop-vo-dun...
# 1558523    https://www.sendo.vn/san-pham/oleo-lampo-longs...
# 1473671    https://www.sendo.vn/san-pham/pin-du-phong-cao...
# 636848     https://www.sendo.vn/san-pham/ao-thun-nam-thoi...
# Name: href, dtype: object

# %%
df_ab['product_name']= df_ab['href'].str.replace('https://www.sendo.vn/san-pham/', '')

# %%
df_ab['product_name']= df_ab['product_name'].str.replace('/"}', '')

# %%
df_ab['product_name'].sample(50)
# Out:
# 770274     may-ep-nuoc-trai-cay-da-nang-manual-juicer-loa...
# 637895     giay-luoi-da-nam-dep-cuc-mem-min-va-em-chan-19...
# 84358          dong-ho-nam-longines-chinh-hang-9039m-2733100
# 109960                    giay-bet-cao-cap-hang-nhap-2989741
# 907372                      sac-du-phong-mi-10400mah-2195892
# 1917654    giay-be-yeu-gb03-824446/?utm_source=facebook&u...
# 1521656                          dam-cong-chua-pinky-3161593
# 626507     hang-loai-1-dam-maxi-hoa-tiet-co-dien-sp00648-...
# 714970     mieng-dan-cuong-luc-man-hinh-oppo-r7-plus-2677305
# 201575     hang-cao-cap-jumsuit-ong-rong-cao-cap-hr694-29...
# 477716     ban-buon-ban-le-loa-nhac-nuoc-hinh-vien-dan-29...
# 714847     ao-somi-caro-cong-so-cuc-dep-3699-hang-nhap-26...
# 2284286                         ac069-ao-thun-co-tim-2970765
# 60297                                  dam-maxi-caro-1093592
# 2216395    hang-nhap-ao-kieu-hoa-tiet-hoa-ha-vy-sp01020-2...
# 2386389                       may-bay-dieu-khien-w25-2706670
# 1100027             may-game-bang-nhua-games-station-2249795
# 69253        kem-duong-da-nivea-q10-plus-anti-falten-2679598
# 1503157    bim-ta-vai-hien-dai-size-m-ban-ngay-danh-cho-b...
# 96866          quan-dai-nu-ran-ri-military-ma-qd1060-3058396
# 1085674                             dam-xoe-phoi-hoa-2226860
# 763187     set-ao-gia-dinh-phoi-soc-do-tre-trung-hgs-199-...
# 440659     hang-nhap-cao-cap-bo-4-tui-xach-nu-han-quoc-tx...
# 302302     ke-giay-inox-treo-tuong-4-tang-hang-viet-nam-1...
# 838369     hang-nhap-ao-kieu-hoa-tiet-hoa-ha-vy-sp01020-2...
# 827732     may-xay-da-nang-panasonic-2913175/?gclid=Cj0KE...
# 806016     hang-nhap-khau-giay-luoi-thoi-trang-gia-tot-31...
# 2068810    hang-loai-1-ao-vol-no-vai-canh-tien-thoi-trang...
# 82996      a-o-thun-tay-lo-mercy-fom-ro-ng-sieu-de-p-nha-...
# 45244      dien-thoai-fpt-x501-gray-thiet-ke-sang-trong-2...
# 358781             dieu-hoa-mini-hongkong-technology-3112360
# 1487778         bo-quan-ao-tap-the-duc-tham-my-tm011-2822115
# 872500     pin-sac-du-phong-xiaomi-10400-mah-sieu-ben-tan...
# 1068210    set-do-bo-vai-cat-hoa-va-bi-hien-dai-2892783/?...
# 1122387    loa-nghe-nhac-bluetooth-the-nho-usb-mini-jy3-1...
# 332769                nk-0606-ao-so-mi-han-quoc-td-97-697190
# 433399     bo-usb-thu-bluetooth-pt-810-wireless-usb-bluet...
# 2284336    https://www.sendo.vn/thoi-trang-nam/ao-khoac/?...
# 1499646    bot-tay-trang-rang-eucryl-tooth-powder-50g-196...
# 955222     duong-shop-hang-loai-1-dam-xoe-cong-chua-co-so...
# 744303     router-wifi-tenda-n630-chuan-n-300mbps-2-anten...
# 1768628                     dep-xop-no-da-co-du-size-3087600
# 238090     ao-kieu-a077-3012658/?trackid=3012658&utm_sour...
# 1113945         bup-be-thay-vay-ao-giay-guong-cho-be-2714492
# 1268712    giay-sandals-2-quai-ngang-verson-8-1898249/?tr...
# 715894     shop-cun-ao-khoac-nam-nu-lo-go-ca-tinh-f0621-1...
# 2271734              may-danh-trung-philips-7-toc-do-2390580
# 2178655    ao-tay-lo-xe-ta-dep-nhe-3008508/?utm_source=fa...
# 913241              hang-cao-cap-ao-thun-la-can-thai-2845424
# 1424683                  balo-day-rut-cung-hoang-dao-3071743
# Name: product_name, dtype: object

# %%
df_ab = df_ab.drop(columns='product_name', axis = 0)

df_ab.sample(10)
# Out:
#                         time  ...                                               href
# 2093302  2016-05-29 09:48:48  ...  https://www.sendo.vn/san-pham/loa-bluetooth-ws...
# 1889764  2016-05-26 14:07:37  ...  https://www.sendo.vn/san-pham/mieng-dan-guitar...
# 581123   2016-05-10 18:14:56  ...  https://www.sendo.vn/san-pham/dien-thoai-fpt-b...
# 351241   2016-05-07 22:47:48  ...  https://www.sendo.vn/san-pham/ao-voan-co-so-mi...
# 1913934  2016-05-26 18:08:45  ...  https://www.sendo.vn/san-pham/nhan-ham-ho-phim...
# 993443   2016-05-15 11:05:58  ...  https://www.sendo.vn/san-pham/ao-khoac-cap-cao...
# 139263   2016-05-05 11:36:59  ...  https://www.sendo.vn/san-pham/quan-short-jean-...
# 1504435  2016-05-21 12:28:19  ...  https://www.sendo.vn/san-pham/mat-kinh-porsche...
# 408774   2016-05-08 21:35:19  ...  https://www.sendo.vn/san-pham/jumpsuit-dai-pho...
# 424574   2016-05-09 08:30:17  ...  https://www.sendo.vn/san-pham/ao-kieu-han-quoc...
#
# [10 rows x 10 columns]

# %%
product_db = df_ac.groupby(by=['belong_cate_lvl3_id', 'product_id', 'href'], as_index = True)['product_id'].unique()

# %%
product_db.to_csv(r'product_ac.csv')

# %%
product1 = pd.read_csv('product_ac.csv', header=None)

# %%
product1.sample(20)
# Out:
#            0  ...          3
# 37625     12  ...  [3008508]
# 343480  1254  ...  [2724204]
# 308206  1060  ...   [374150]
# 390294  1370  ...  [2188638]
# 321503  1125  ...  [2714774]
# 266136   699  ...  [3059356]
# 494331  1665  ...  [2914085]
# 85201     54  ...  [3010537]
# 69567     31  ...  [3260531]
# 327488  1155  ...  [2532469]
# 360253  1286  ...  [2820321]
# 570390  1772  ...  [2307021]
# 578602  1777  ...  [2310508]
# 310825  1066  ...  [3230747]
# 152730   265  ...  [3080590]
# 33678     12  ...  [2712911]
# 445262  1410  ...  [2910631]
# 121646   110  ...  [1898448]
# 488303  1614  ...  [2832595]
# 238756   698  ...  [2137332]
#
# [20 rows x 4 columns]

# %%
product1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643385 entries, 0 to 643384
# Data columns (total 4 columns):
# 0    643385 non-null int64
# 1    643385 non-null int64
# 2    643385 non-null object
# 3    643385 non-null object
# dtypes: int64(2), object(2)
# memory usage: 19.6+ MB

# %%
product1.head(50)
# Out:
#            0  ...          3
# 0         10  ...    [82151]
# 1         10  ...    [82155]
# 2         10  ...   [133494]
# 3         10  ...   [178167]
# 4         10  ...   [189823]
# ...      ...  ...        ...
# 657070  1905  ...  [3226925]
# 657071  1905  ...  [3229175]
# 657072  1905  ...  [3230171]
# 657073  1905  ...  [3230753]
# 657074  1907  ...  [1333281]
#
# [516354 rows x 4 columns]

# %%
product_db_new = pd.DataFrame(columns=['product_id','href','id_cate'])

# %%
product_db_new['product_id'] =  product1[1]
product_db_new['href'] =  product1[2].str.replace('"}','')
product_db_new['id_cate'] =  product1[0]

# %%
product_db_new['href'] =  product_db_new['href'].str.replace('https://www.sendo.vn/','')

# %%
product_db_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643385 entries, 0 to 643384
# Data columns (total 3 columns):
# product_id    643385 non-null int64
# href          643385 non-null object
# id_cate       643385 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 14.7+ MB

# %%
product_db_new.head(10)
# Out:
#    product_id                                               href  id_cate
# 0       59701     san-pham/ao-so-mi-that-no-kieu-han-quoc-59701/       10
# 1       65028       san-pham/ao-so-mi-cach-dieu-co-la-sen-65028/       10
# 2       68168               san-pham/ao-so-mi-kieu-c20123-68168/       10
# 3       82174              san-pham/ao-so-mi-den-huyen-bi-82174/       10
# 4      107496  san-pham/sucashop-ao-so-mi-sc-tay-cham-bi-107496/       10
# 5      110419                  san-pham/ao-so-mi-yoshino-110419/       10
# 6      111234         san-pham/so-mi-co-tru-dai-tay-a077-111234/       10
# 7      111372                    san-pham/ao-so-mi-no-co-111372/       10
# 8      119132          san-pham/lamchic-ao-somi-hoa-tiet-119132/       10
# 9      127726  san-pham/kerry-shop-ao-so-mi-cham-bi-hong-kong...       10

# %%
product_db_new.to_csv(r'product_ac.csv')

# %%
product_db_new1.sample(10
                       )
# Out:
#         Unnamed: 0  ...                                            id_cate
# 99698        99698  ...    (2441758, 273708    698\nName: 0, dtype: int64)
# 302724      302724  ...   (3162251, 463010    1404\nName: 0, dtype: int64)
# 197994      197994  ...   (2919917, 526031    1667\nName: 0, dtype: int64)
# 290679      290679  ...      (3136071, 45042    12\nName: 0, dtype: int64)
# 32315        32315  ...   (1450299, 468482    1410\nName: 0, dtype: int64)
# 183158      183158  ...  (2872505, 221707    546\n221708    546\nName: ...
# 21400        21400  ...   (1241955, 593720    1773\nName: 0, dtype: int64)
# 235799      235799  ...      (3019963, 43437    12\nName: 0, dtype: int64)
# 262837      262837  ...   (3082571, 482383    1449\nName: 0, dtype: int64)
# 92040        92040  ...    (2386123, 291784    699\nName: 0, dtype: int64)
#
# [10 rows x 4 columns]

# %%
product_user = df_ab.groupby(by=['user_id', 'product_id'], as_index = True)['product_id'].unique()
product_user
# Out:
# user_id                           product_id
# 000070AD27611BAD348048F741DF5B19  3091102       [3091102]
#                                   3093492       [3093492]
# 0000F347DB2A9579AE40DE16C878E0B0  2552592       [2552592]
# 0000FF678FE631FB03A067F4DAC6F45A  2265512       [2265512]
# 00010EA0E144B2D6E652B894A87EE507  2690123       [2690123]
#                                                   ...
# FFFFAB920C0D044E678B261FAA01F795  3115993       [3115993]
#                                   3185025       [3185025]
#                                   3186839       [3186839]
#                                   3192931       [3192931]
#                                   3233495       [3233495]
# Name: product_id, Length: 1758870, dtype: object

# %%
product_user.to_csv(r'product_user.csv')

# %%
product_user1 = pd.read_csv('product_user.csv', header= None)

# %%
product_user1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1758870 entries, 0 to 1758869
# Data columns (total 3 columns):
# 0    object
# 1    int64
# 2    object
# dtypes: int64(1), object(2)
# memory usage: 40.3+ MB

# %%
product_user1.head(30)
# Out:
#                                    0        1          2
# 0   000070AD27611BAD348048F741DF5B19  3091102  [3091102]
# 1   000070AD27611BAD348048F741DF5B19  3093492  [3093492]
# 2   0000F347DB2A9579AE40DE16C878E0B0  2552592  [2552592]
# 3   0000FF678FE631FB03A067F4DAC6F45A  2265512  [2265512]
# 4   00010EA0E144B2D6E652B894A87EE507  2690123  [2690123]
# 5   00012E7446373FB0EDE068F62CA61966  2337580  [2337580]
# 6   000135C418704DE7367363330BF3536F  2403242  [2403242]
# 7   000135C418704DE7367363330BF3536F  2415436  [2415436]
# 8   000135C418704DE7367363330BF3536F  2577199  [2577199]
# 9   000135C418704DE7367363330BF3536F  2605562  [2605562]
# 10  000135C418704DE7367363330BF3536F  2616684  [2616684]
# 11  000135C418704DE7367363330BF3536F  2669079  [2669079]
# 12  000135C418704DE7367363330BF3536F  2670416  [2670416]
# 13  000135C418704DE7367363330BF3536F  2727261  [2727261]
# 14  000135C418704DE7367363330BF3536F  2824034  [2824034]
# 15  000135C418704DE7367363330BF3536F  2964100  [2964100]
# 16  000135C418704DE7367363330BF3536F  3022847  [3022847]
# 17  000135C418704DE7367363330BF3536F  3046801  [3046801]
# 18  000135C418704DE7367363330BF3536F  3052676  [3052676]
# 19  000135C418704DE7367363330BF3536F  3052723  [3052723]
# 20  000135C418704DE7367363330BF3536F  3162206  [3162206]
# 21  000135C418704DE7367363330BF3536F  3184001  [3184001]
# 22  000135C418704DE7367363330BF3536F  3218141  [3218141]
# 23  000135C418704DE7367363330BF3536F  3221138  [3221138]
# 24  00018586640750B168513AE56676296E  3048949  [3048949]
# 25  0001CAC4C634E072ADA2A2026F690505  2911161  [2911161]
# 26  0002033148EC1751FED25EE4E8A44794  2201664  [2201664]
# 27  0002033148EC1751FED25EE4E8A44794  2837679  [2837679]
# 28  0002033148EC1751FED25EE4E8A44794  2874743  [2874743]
# 29  0002033148EC1751FED25EE4E8A44794  2943671  [2943671]

# %%
product_user2 = pd.DataFrame(columns=['user_id', 'product_id'])

# %%
product_user2['user_id'] = product_user1[0]
product_user2['product_id'] = product_user1[1]

# %%
product_user2.to_csv(r'product_user.csv')

# %%
product_useraa = pd.read_csv('product_useraa.csv')
product_useraa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1773861 entries, 0 to 1773860
# Data columns (total 3 columns):
# Unnamed: 0    int64
# user_id       object
# product_id    int64
# dtypes: int64(2), object(1)
# memory usage: 40.6+ MB

# %%
product_user2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1758870 entries, 0 to 1758869
# Data columns (total 2 columns):
# user_id       object
# product_id    int64
# dtypes: int64(1), object(1)
# memory usage: 26.8+ MB

# %%
product_useraa.drop(columns='Unnamed: 0')
# Out:
#                                   user_id  product_id
# 0        000021E7765634E8A1A1E27DE21E7DF3      765942
# 1        000021E7765634E8A1A1E27DE21E7DF3     3037477
# 2        00003D04C11A33F674B8F64CB1BAA004     2249761
# 3        00003D04C11A33F674B8F64CB1BAA004     2796826
# 4        00005F933267D65FF8159DC1A6C70925     2569826
# ...                                   ...         ...
# 1773856  FFFF9ABF51D864A05C7F140C7E7EF138     2917920
# 1773857  FFFF9ABF51D864A05C7F140C7E7EF138     2948789
# 1773858  FFFF9ABF51D864A05C7F140C7E7EF138     2949608
# 1773859  FFFF9ABF51D864A05C7F140C7E7EF138     2951354
# 1773860  FFFF9ABF51D864A05C7F140C7E7EF138     2990115
#
# [1773861 rows x 2 columns]

# %%
final_pd_us = pd.concat([product_user2,product_useraa], axis=0, join='inner')

# %%
final_pd_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3532731 entries, 0 to 1773860
# Data columns (total 2 columns):
# user_id       object
# product_id    int64
# dtypes: int64(1), object(1)
# memory usage: 80.9+ MB

# %%
product_user3 = final_pd_us.groupby(by=['user_id', 'product_id'], as_index = True)['product_id'].unique()
product_user3
# Out:
# user_id                           product_id
# 000021E7765634E8A1A1E27DE21E7DF3  765942         [765942]
#                                   3037477       [3037477]
# 00003D04C11A33F674B8F64CB1BAA004  2249761       [2249761]
#                                   2796826       [2796826]
# 00005F933267D65FF8159DC1A6C70925  2569826       [2569826]
#                                                   ...
# FFFFAB920C0D044E678B261FAA01F795  3115993       [3115993]
#                                   3185025       [3185025]
#                                   3186839       [3186839]
#                                   3192931       [3192931]
#                                   3233495       [3233495]
# Name: product_id, Length: 3490274, dtype: object

# %%
product_user3.to_csv(r'final_pd_user.csv')

# %%
fn_pd_u = pd.read_csv('final_pd_user.csv', header=None)

# %%
fn_pd_u.head(20)
# Out:
#                                    0        1          2
# 0   000021E7765634E8A1A1E27DE21E7DF3   765942   [765942]
# 1   000021E7765634E8A1A1E27DE21E7DF3  3037477  [3037477]
# 2   00003D04C11A33F674B8F64CB1BAA004  2249761  [2249761]
# 3   00003D04C11A33F674B8F64CB1BAA004  2796826  [2796826]
# 4   00005F933267D65FF8159DC1A6C70925  2569826  [2569826]
# 5   000070AD27611BAD348048F741DF5B19  3091102  [3091102]
# 6   000070AD27611BAD348048F741DF5B19  3093492  [3093492]
# 7   0000C89FF2311CE11E9D9FB5B0C38BD1   948229   [948229]
# 8   0000C89FF2311CE11E9D9FB5B0C38BD1  1438849  [1438849]
# 9   0000C89FF2311CE11E9D9FB5B0C38BD1  1945467  [1945467]
# 10  0000C89FF2311CE11E9D9FB5B0C38BD1  2038106  [2038106]
# 11  0000C89FF2311CE11E9D9FB5B0C38BD1  2202496  [2202496]
# 12  0000C89FF2311CE11E9D9FB5B0C38BD1  2476744  [2476744]
# 13  0000C89FF2311CE11E9D9FB5B0C38BD1  2484880  [2484880]
# 14  0000C89FF2311CE11E9D9FB5B0C38BD1  2494876  [2494876]
# 15  0000C89FF2311CE11E9D9FB5B0C38BD1  2835160  [2835160]
# 16  0000C89FF2311CE11E9D9FB5B0C38BD1  2941367  [2941367]
# 17  0000E78EE6184DBD861594816DF3F8A9  2994821  [2994821]
# 18  0000F347DB2A9579AE40DE16C878E0B0  2552592  [2552592]
# 19  0000FF678FE631FB03A067F4DAC6F45A  2265512  [2265512]

# %%
fn_pd_u1 = pd.DataFrame(columns=['user_id','product_id'])

# %%
fn_pd_u1['user_id'] = fn_pd_u[0]
fn_pd_u1['product_id']=fn_pd_u[1]

# %%
fn_pd_u1.to_csv(r'final_pd_user.csv')
