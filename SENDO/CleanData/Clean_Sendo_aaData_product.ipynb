# %%
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")

# %%
# Code to read csv file into Colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Fill the blanks
link = "https://drive.google.com/open?id="
fluff, id = link.split('=')

downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('sendo-aa.csv')  
data = pd.read_csv('sendo-aa.csv')
#data = data[0].str.split(',', expand=True)
# Show first 5 rows of dataset
data.sample(5)
# Out:
#          Unnamed: 0  ...                                               href
# 880999       880999  ...  https://www.sendo.vn/san-pham/dep-xo-ngon-quai...
# 946665       946665  ...  https://www.sendo.vn/san-pham/hang-loai-1-ao-s...
# 1945558     1945558  ...  https://www.sendo.vn/san-pham/xe-dieu-khien-tu...
# 1935801     1935801  ...  https://www.sendo.vn/san-pham/quat-da-mini-mot...
# 2289028     2289028  ...  https://www.sendo.vn/san-pham/gel-mat-ong-duon...
#
# [5 rows x 11 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398354 entries, 0 to 2398353
# Data columns (total 11 columns):
# Unnamed: 0               int64
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(5), object(6)
# memory usage: 201.3+ MB

# %%
df_aa = data.drop(columns='Unnamed: 0', axis = 0)

df_aa.sample(10)
# Out:
#                         time  ...                                               href
# 1042898  2016-04-13 17:40:47  ...  https://www.sendo.vn/san-pham/bo-the-thao-tap-...
# 2357082  2016-05-02 21:54:42  ...  https://www.sendo.vn/san-pham/set-alibaba-lung...
# 1006989  2016-04-13 11:46:32  ...  https://www.sendo.vn/san-pham/usb-chuyen-loa-t...
# 861136   2016-04-11 16:00:18  ...  https://www.sendo.vn/san-pham/dam-ren-xoe-tay-...
# 556562   2016-04-07 13:40:06  ...  https://www.sendo.vn/san-pham/dao-xep-hinh-the...
# 1997816  2016-04-27 10:00:09  ...  https://www.sendo.vn/san-pham/dam-co-v-cach-di...
# 1260752  2016-04-16 21:43:09  ...  https://www.sendo.vn/san-pham/ao-voan-hoa-dep-...
# 1139532  2016-04-14 21:45:54  ...  https://www.sendo.vn/san-pham/ao-khoac-the-tha...
# 1336199  2016-04-18 11:04:02  ...  https://www.sendo.vn/san-pham/set-bo-do-bd2501...
# 2383670  2016-05-03 11:56:59  ...  https://www.sendo.vn/san-pham/khuon-lam-gio-xa...
#
# [10 rows x 10 columns]

# %%
data[data['user_id'] == '003DC7236237BCA6094AE33F99CF06E9']
# Out:
#          Unnamed: 0  ...                                               href
# 270847       270847  ...  https://www.sendo.vn/san-pham/tui-deo-cheo-sup...
# 270990       270990  ...  https://www.sendo.vn/san-pham/tui-deo-cheo-sup...
# 271021       271021  ...  https://www.sendo.vn/san-pham/tui-deo-cheo-sup...
# 271084       271084  ...  https://www.sendo.vn/san-pham/tui-deo-cheo-sup...
# 271164       271164  ...  https://www.sendo.vn/san-pham/tui-deo-cheo-sup...
# 460707       460707  ...  https://www.sendo.vn/san-pham/sieu-hot-ao-dai-...
# 663732       663732  ...  https://www.sendo.vn/san-pham/chan-vay-jean-fo...
# 988815       988815  ...  https://www.sendo.vn/san-pham/set-nguyen-bo-qu...
# 1001683     1001683  ...  https://www.sendo.vn/san-pham/set-nguyen-bo-qu...
# 1005190     1005190  ...  https://www.sendo.vn/san-pham/set-quan-rong-ao...
# 1005320     1005320  ...  https://www.sendo.vn/san-pham/set-ao-lien-quan...
# 1005465     1005465  ...  https://www.sendo.vn/san-pham/co-anh-that-3-ma...
# 1005577     1005577  ...  https://www.sendo.vn/san-pham/dh621101-dam-om-...
# 1005699     1005699  ...  https://www.sendo.vn/san-pham/dam-suong-tui-ho...
# 1005762     1005762  ...  https://www.sendo.vn/san-pham/dam-xuong-tay-be...
# 1006239     1006239  ...  https://www.sendo.vn/san-pham/dam-xoe-thun-den...
# 1006312     1006312  ...  https://www.sendo.vn/san-pham/dam-xoe-cheo-lun...
# 1006354     1006354  ...  https://www.sendo.vn/san-pham/dam-xoe-duoi-ca-...
# 1006433     1006433  ...  https://www.sendo.vn/san-pham/dam-xoe-duoi-ca-...
# 1006497     1006497  ...  https://www.sendo.vn/san-pham/dam-suong-nu-co-...
# 1006516     1006516  ...  https://www.sendo.vn/san-pham/dam-suong-nu-co-...
# 1006569     1006569  ...  https://www.sendo.vn/san-pham/dam-suong-co-tru...
# 1006674     1006674  ...  https://www.sendo.vn/san-pham/dam-suong-phoi-c...
# 1006717     1006717  ...  https://www.sendo.vn/san-pham/dam-suong-phoi-c...
# 1006795     1006795  ...  https://www.sendo.vn/san-pham/dam-suong-bo-xam...
# 1006922     1006922  ...  https://www.sendo.vn/san-pham/dam-yem-thun-ren...
# 1007044     1007044  ...  https://www.sendo.vn/san-pham/dam-suong-ke-soc...
# 1007149     1007149  ...  https://www.sendo.vn/san-pham/dam-oversize-phu...
# 1007213     1007213  ...  https://www.sendo.vn/san-pham/dam-suong-co-yem...
# 1300693     1300693  ...  https://www.sendo.vn/san-pham/dam-thun-fom-ron...
# 1300708     1300708  ...  https://www.sendo.vn/san-pham/dam-thun-fom-ron...
# 1300715     1300715  ...  https://www.sendo.vn/san-pham/dam-thun-fom-ron...
# 1300890     1300890  ...  https://www.sendo.vn/san-pham/dam-oversize-phu...
# 1300934     1300934  ...  https://www.sendo.vn/san-pham/dam-suong-2-tui-...
# 1301524     1301524  ...  https://www.sendo.vn/san-pham/dam-oversize-phu...
# 1301852     1301852  ...  https://www.sendo.vn/san-pham/dam-suong-ngoai-...
# 1302701     1302701  ...  https://www.sendo.vn/san-pham/dam-xoe-co-peter...
# 1303361     1303361  ...  https://www.sendo.vn/san-pham/dam-summer-mua-h...
# 1303624     1303624  ...  https://www.sendo.vn/san-pham/dam-xoe-2-kieu-2...
# 1304014     1304014  ...  https://www.sendo.vn/san-pham/dam-green-co-sen...
# 1367509     1367509  ...  https://www.sendo.vn/san-pham/hang-nhap-chan-v...
# 1368071     1368071  ...  https://www.sendo.vn/san-pham/chan-vay-xep-ly-...
# 1368370     1368370  ...  https://www.sendo.vn/san-pham/chan-vay-cong-so...
# 1368773     1368773  ...  https://www.sendo.vn/san-pham/quan-vay-ngan-xi...
# 1369981     1369981  ...  https://www.sendo.vn/san-pham/chan-vay-om-ngan...
# 1649497     1649497  ...  https://www.sendo.vn/san-pham/tui-xach-da-cao-...
# 1651548     1651548  ...  https://www.sendo.vn/san-pham/chan-vay-xoe-lun...
# 1688211     1688211  ...  https://www.sendo.vn/san-pham/giay-the-thao-ls...
# 1719198     1719198  ...  https://www.sendo.vn/san-pham/sieu-hot-ao-dai-...
# 1719247     1719247  ...  https://www.sendo.vn/san-pham/vay-ngu-voan-thu...
# 1719265     1719265  ...  https://www.sendo.vn/san-pham/tui-deo-cheo-sup...
# 1887397     1887397  ...  https://www.sendo.vn/san-pham/quan-lot-nam-thi...
# 2139600     2139600  ...  https://www.sendo.vn/san-pham/quan-ong-rong-29...
#
# [53 rows x 11 columns]

# %%
data[data['product_id'] == 2918041]
# Out:
#          Unnamed: 0  ...                                               href
# 43716         43716  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 58729         58729  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 91015         91015  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 165687       165687  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 229733       229733  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 317131       317131  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 317299       317299  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 323294       323294  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 472201       472201  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 481029       481029  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 527470       527470  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 610229       610229  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 610551       610551  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 611277       611277  ...  https://www.sendo.vn/san-pham/dam-xoe-du-tiec-...
# 658613       658613  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 659259       659259  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 769650       769650  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 912355       912355  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 949183       949183  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 950130       950130  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1041599     1041599  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1090171     1090171  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1090926     1090926  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1141514     1141514  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1186104     1186104  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1192848     1192848  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1199020     1199020  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1208268     1208268  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1210364     1210364  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1210482     1210482  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1210946     1210946  ...  https://www.sendo.vn/thoi-trang-nu/dam/dam-xoe/"}
# 1215666     1215666  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1220587     1220587  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1323942     1323942  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1427834     1427834  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1464110     1464110  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1537907     1537907  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1567664     1567664  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1622240     1622240  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1622285     1622285  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1741939     1741939  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1757111     1757111  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1811463     1811463  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 1871184     1871184  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 2033185     2033185  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 2072480     2072480  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 2114375     2114375  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 2159134     2159134  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 2352488     2352488  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
# 2397971     2397971  ...  https://www.sendo.vn/san-pham/hang-nhap-cao-ca...
#
# [50 rows x 11 columns]

# %%
user_aa = pd.DataFrame(columns=['user_id'])

# %%
user_aa['user_id'] = df_aa['user_id'].unique()

# %%
user_aa['user_id'].nunique()
# Out:
# 341104

# %%
user_aa.to_csv(r'user_aa.csv')

# %%
df_aa[df_aa['product_id'] == 2975485]['href']
# Out:
# 1501958    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# 1578546    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# 1914792    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# 1914873    https://www.sendo.vn/?utm_source=laban&utm_med...
# 2194031    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# 2210166    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# 2210315    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# 2210436    https://www.sendo.vn/san-pham/dong-ho-day-du-q...
# Name: href, dtype: object

# %%
df_aa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398354 entries, 0 to 2398353
# Data columns (total 10 columns):
# time                     object
# user_id                  object
# product_id               int64
# belong_cate_lvl1_id      int64
# belong_cate_lvl2_id      int64
# belong_cate_lvl3_id      int64
# belong_cate_lvl1_name    object
# belong_cate_lvl2_name    object
# belong_cate_lvl3_name    object
# href                     object
# dtypes: int64(4), object(6)
# memory usage: 183.0+ MB

# %%
df_time = pd.DataFrame(columns=['time', 'user_id', 'product_id'])

# %%
df_time['time'] = df_aa['time']
df_time['user_id'] = df_aa['user_id']
df_time['product_id'] = df_aa['product_id']

# %%
df_time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2398354 entries, 0 to 2398353
# Data columns (total 3 columns):
# time          object
# user_id       object
# product_id    int64
# dtypes: int64(1), object(2)
# memory usage: 54.9+ MB

# %%
df_time.to_csv(r'time_user_product.csv')

# %%
df_time.sample(20)
# Out:
#                         time                           user_id  product_id
# 794988   2016-04-10 19:33:54  4E19D3A9E9D3EB1F96FC3FDE3C6CD828     2593050
# 967291   2016-04-12 20:55:55  581DD9212CE802908085C2F890742F81     2460411
# 184709   2016-04-02 12:30:25  F8BFCDDA054E5B7BFBC2397E78EC0178     2369611
# 2205971  2016-04-29 20:01:51  7501169861D78B18A2FD8FB38856F643     2926692
# 1783318  2016-04-24 10:07:42  C2E9B5CC5599796D923BB12D7B0BA2E2     2901212
# 1514718  2016-04-20 15:09:12  79E7517DE80221F8085896CBDEEC5571     1989569
# 82077    2016-03-31 22:38:06  ABB7B3CEC3DD8D4101DF7D66E4232464     2599563
# 856586   2016-04-11 15:19:48  AD949D6A21C553B25BF8D3E3D7646E2B     2466580
# 1510913  2016-04-20 14:36:19  059FF24BFDA069962E7971A4CD1593AB     3015850
# 737845   2016-04-09 19:52:12  3CA91DCA0BECC9BB5743081F32B2932A     2899729
# 26923    2016-03-31 11:30:56  8D77CC37060CCFC98C18DDBF8675303C     1060795
# 1022863  2016-04-13 14:36:28  C99C823BF288A4FAE61506BA597D5F1E     2883550
# 552401   2016-04-07 12:46:30  E92B83C6DF174681A6618B3A00ECBB40     2058472
# 690313   2016-04-09 07:20:27  602491CB649106B0F925BEFDF56A1DDD     2865280
# 653315   2016-04-08 15:53:06  05435B0559311D22B81A50FEC5E70BC5     1455493
# 727581   2016-04-09 16:38:30  33D9AE95CE1C03A6ADE8DAB5179FFD02     2764615
# 2215638  2016-04-29 22:47:38  148B879EC7E850451DDD4DBCD21689D0     2262165
# 1910280  2016-04-26 00:03:03  A2E85464154BE4F3F7D20DE414AA49D1     2934427
# 2272886  2016-05-01 10:14:48  519E23D6DF6B378E900CB84F57EE6126     2976659
# 616218   2016-04-08 09:43:38  36405FF4A0A5668E0C5D8F7570D86961     2958075

# %%
#df_ab['href'].sample(10)

# %%
#df_ab['product_name']= df_ab['href'].str.replace('https://www.sendo.vn/san-pham/', '')

# %%
#df_ab['product_name']= df_ab['product_name'].str.replace('/"}', '')

# %%
#df_ab['product_name'].sample(50)

# %%
#df_ab = df_ab.drop(columns='product_name', axis = 0)

#df_ab.sample(10)

# %%
product_db = df_aa.groupby(by=['belong_cate_lvl3_id','product_id','href'], as_index = True)

# %%
product_db = product_db['product_id'].unique()

# %%
product_db.to_csv(r'product_aa.csv')

# %%
product_db2 = pd.read_csv('product_aa.csv', header= None)
product_db2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655090 entries, 0 to 655089
# Data columns (total 4 columns):
# 0    655090 non-null int64
# 1    655090 non-null int64
# 2    655090 non-null object
# 3    655090 non-null object
# dtypes: int64(2), object(2)
# memory usage: 20.0+ MB

# %%
product_db2.head(10)
# Out:
#     0       1                                                  2         3
# 0  10   38491  https://www.sendo.vn/san-pham/ao-so-mi-p2058-3...   [38491]
# 1  10   48730          https://www.sendo.vn/san-pham/ao-48730/"}   [48730]
# 2  10   48823    https://www.sendo.vn/san-pham/ao-so-mi-48823/"}   [48823]
# 3  10   70702  https://www.sendo.vn/thoi-trang-nu/ao-nu/ao-so...   [70702]
# 4  10   82174  https://www.sendo.vn/san-pham/ao-so-mi-den-huy...   [82174]
# 5  10  102711  https://www.sendo.vn/san-pham/ao-so-mi-kieu-sm...  [102711]
# 6  10  106143  https://www.sendo.vn/san-pham/ao-so-mi-style-k...  [106143]
# 7  10  136261  https://www.sendo.vn/san-pham/kim-lien-ao-so-m...  [136261]
# 8  10  156023  https://www.sendo.vn/san-pham/kim-lien-ao-tran...  [156023]
# 9  10  166087  https://www.sendo.vn/san-pham/womaninlove-ao-v...  [166087]

# %%
product_db1 = pd.DataFrame(columns = ['product_id', 'href','id_cate'])

# %%
product_db1['product_id'] = product_db2[1]
product_db1['id_cate'] = product_db2[0]
product_db1['href'] = product_db2[2].str.replace('"}','')
product_db1.head(20)
# Out:
#     product_id                                               href  id_cate
# 0        38491  https://www.sendo.vn/san-pham/ao-so-mi-p2058-3...       10
# 1        48730            https://www.sendo.vn/san-pham/ao-48730/       10
# 2        48823      https://www.sendo.vn/san-pham/ao-so-mi-48823/       10
# 3        70702  https://www.sendo.vn/thoi-trang-nu/ao-nu/ao-so...       10
# 4        82174  https://www.sendo.vn/san-pham/ao-so-mi-den-huy...       10
# 5       102711  https://www.sendo.vn/san-pham/ao-so-mi-kieu-sm...       10
# 6       106143  https://www.sendo.vn/san-pham/ao-so-mi-style-k...       10
# 7       136261  https://www.sendo.vn/san-pham/kim-lien-ao-so-m...       10
# 8       156023  https://www.sendo.vn/san-pham/kim-lien-ao-tran...       10
# 9       166087  https://www.sendo.vn/san-pham/womaninlove-ao-v...       10
# 10      176725  https://www.sendo.vn/san-pham/ao-so-mi-trang-c...       10
# 11      183848  https://www.sendo.vn/san-pham/ao-so-mi-voan-mi...       10
# 12      189823  https://www.sendo.vn/san-pham/ao-voan-co-tru-t...       10
# 13      190185  https://www.sendo.vn/san-pham/ao-so-mi-tay-nep...       10
# 14      193980  https://www.sendo.vn/san-pham/ao-so-mi-voan-co...       10
# 15      198287  https://www.sendo.vn/san-pham/ao-so-mi-hong-ta...       10
# 16      201692  https://www.sendo.vn/san-pham/ao-voan-co-tru-t...       10
# 17      203967  https://www.sendo.vn/san-pham/ao-so-mi-cong-so...       10
# 18      209208  https://www.sendo.vn/san-pham/ao-so-mi-canh-do...       10
# 19      212373  https://www.sendo.vn/san-pham/ao-so-mi-nu-caro...       10

# %%
product_db1['href'] = product_db1['href'].str.replace('https://www.sendo.vn/','')
product_db1.head(20)
# Out:
#     product_id                                               href  id_cate
# 0        38491                     san-pham/ao-so-mi-p2058-38491/       10
# 1        48730                                 san-pham/ao-48730/       10
# 2        48823                           san-pham/ao-so-mi-48823/       10
# 3        70702  thoi-trang-nu/ao-nu/ao-so-mi-cong-so/sucashop-...       10
# 4        82174              san-pham/ao-so-mi-den-huyen-bi-82174/       10
# 5       102711              san-pham/ao-so-mi-kieu-sm0059-102711/       10
# 6       106143              san-pham/ao-so-mi-style-korea-106143/       10
# 7       136261  san-pham/kim-lien-ao-so-mi-form-dai-khoet-giot...       10
# 8       156023  san-pham/kim-lien-ao-trang-nep-xanh-la-sanh-di...       10
# 9       166087  san-pham/womaninlove-ao-voan-trang-tay-cutout-...       10
# 10      176725    san-pham/ao-so-mi-trang-cao-cap-sm30061-176725/       10
# 11      183848                san-pham/ao-so-mi-voan-mimi-183848/       10
# 12      189823         san-pham/ao-voan-co-tru-thoi-trang-189823/       10
# 13      190185    san-pham/ao-so-mi-tay-nep-kieu-han-quoc-190185/       10
# 14      193980  san-pham/ao-so-mi-voan-cong-so-han-quoc-ma-am4...       10
# 15      198287             san-pham/ao-so-mi-hong-tay-dai-198287/       10
# 16      201692  san-pham/ao-voan-co-tru-thoi-trang-han-quoc-20...       10
# 17      203967            san-pham/ao-so-mi-cong-so-mss97-203967/       10
# 18      209208                 san-pham/ao-so-mi-canh-doi-209208/       10
# 19      212373  san-pham/ao-so-mi-nu-caro-thanh-lich-ma-am427-...       10

# %%
product_db1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 655090 entries, 0 to 655089
# Data columns (total 3 columns):
# product_id    655090 non-null int64
# href          655090 non-null object
# id_cate       655090 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 15.0+ MB

# %%
product_db1['product_id'].nunique()
# Out:
# 321098

# %%
product_db1.to_csv(r'product_aa.csv')

# %%
#product_db1['href'] = df_aa['href'].where( product_db1['product_id'] == df_aa['product_id'])

# %%
#product_db1.info()

# %%
#product_db.to_csv(r'product1.csv')

# %%
#product1 = pd.read_csv('product1.csv', header=None)

# %%
#product1.sample(20)

# %%
#product1 = product1.groupby(by=[1])

# %%
#product1.head(50)

# %%
#product_db_new = pd.DataFrame(columns=['product_id','href','id_cate'])

# %%
#product_db_new['product_id'] =  product1[1]
#product_db_new['href'] =  product1[2]
#product_db_new['id_cate'] =  product1[0]

# %%
#product_db_new.info()

# %%
#product_db_new1 = pd.read_csv('product2.csv')
